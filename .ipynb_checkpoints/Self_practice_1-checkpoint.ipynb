# %% [markdown]
# ## 魔術指令

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
pi
# Out:
# 3.141592653589793

# %%
sin(pi/2)
# Out:
# 1.0

# %%
plot([-2, 10, 3, 13, 5])

# %%
randn(10)
## 從 normal distribution 找出的亂數(平均=0, 標準差/變異數=1)
# Out:
# array([ 2.59908327, -0.76159614,  0.13183728, -0.83275976,  0.72532246,
#        -1.42955003, -0.11878899, -0.02665835, -1.37236958,  0.11548463])

# %%
plot(randn(100))

# %%
plot([-2, 1, 2.7, 3.3], [3, -5, 6, 0])

# %% [markdown]
# ## 連結
# [我的github](https://github.com/rainstop1205)

# %% [markdown]
# ## 插入圖片
# ![雄大&兔兔](sticker.png)

# %% [markdown]
# ## 打數學符號
# 有一函數 $f(x) = x^3 + 2x^2 + 5$, 做積分:
# $$\int_a^b f(x) \, dx$$

# %% [markdown]
# ## 變數名稱可用中文

# %%
底 = 3
高 = 5

# %%
面積 = (底 * 高) / 2
面積
# Out:
# 7.5

# %% [markdown]
# ## 定義 List(串列)

# %%
L = [3, 9, 10, 2, -3, -5]
plot(L)

# %% [markdown]
# ## List 做加減乘除

# %%
L = [3, 87, -5, 9]
G = [1, 2, 8, 10]

# %%
L + G
# Out:
# [3, 87, -5, 9, 1, 2, 8, 10]

# %%
L - G
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-9d7050e65523> in <module>()
# ----> 1 L - G
#
# TypeError: unsupported operand type(s) for -: 'list' and 'list'

# %% [markdown]
# ##  純量乘法

# %%
L
# Out:
# [3, 87, -5, 9]

# %%
3*L
# Out:
# [3, 87, -5, 9, 3, 87, -5, 9, 3, 87, -5, 9]

# %% [markdown]
# ## Hello, World!

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ## 字串

# %%
name = "Yuting" ## 單雙引號都可以，前後一致即可
print(name)
# Out:
# Yuting

# %% [markdown]
# ## 字串相加

# %%
name
# Out:
# 'Yuting'

# %%
"hello, " + name + "!"
# Out:
# 'hello, Yuting!'

# %%
name = "Yuting"
print("Hello, " + name)
# Out:
# Hello, Yuting

# %%
hi = "Hi! "
name = "Yuting"
hi + name
# Out:
# 'Hi! Yuting'

# %% [markdown]
# ## k倍的字串

# %%
emoji = "╮(╯▽╰)╭"
5 * emoji
# Out:
# '╮(╯▽╰)╭╮(╯▽╰)╭╮(╯▽╰)╭╮(╯▽╰)╭╮(╯▽╰)╭'

# %% [markdown]
# ## 神奇三引號

# %%
message = '''我來示範
中間換行
像這樣。
'''
print(message)
# Out:
# 我來示範
# 中間換行
# 像這樣。

# %%
message
# Out:
# '我來示範\n中間換行\n像這樣。\n'
